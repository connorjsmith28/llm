# %%
import os 
os.environ['HF_TOKEN'] = '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'
import transformers
import torch

# %%
# basic model
model_id = 'meta-llama/Meta-Llama-3-8B'

pipeline = transformers.pipeline(
    "text-generation", model=model_id, device_map="auto"
)

pipeline("How do I build a simple chat bot using hugging face, llama3, and a local jupyter notebook?")
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# WARNING:root:Some parameters are on the meta device device because they were offloaded to the disk and cpu.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 8
#       2 model_id = 'meta-llama/Meta-Llama-3-8B'
#       4 pipeline = transformers.pipeline(
#       5     "text-generation", model=model_id, device_map="auto"
#       6 )
# ----> 8 pipeline("How do I build a simple chat bot using hugging face, llama3, and a local jupyter notebook?")
#
# ...
