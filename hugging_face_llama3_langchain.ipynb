# %%
import os 
os.environ['HF_TOKEN'] = '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'
import transformers
import torch

# %%
# basic model
model_id = 'meta-llama/Meta-Llama-3-8B'

pipeline = transformers.pipeline(
    "question-answering", model=model_id, device_map="auto"
)

pipeline(question="How do I build a simple chat bot using hugging face, llama3, and a local jupyter notebook?")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 4
#       1 # basic model
#       2 model_id = 'meta-llama/Meta-Llama-3-8B'
# ----> 4 pipeline = transformers.pipeline(
#       5     "question-answering", model=model_id, device_map="auto"
#       6 )
#       8 pipeline(question="How do I build a simple chat bot using hugging face, llama3, and a local jupyter notebook?")
#
# File ~\AppData\Local\Programs\Python\Lib\site-packages\transformers\pipelines\__init__.py:906, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     904 if isinstance(model, str) or framework is None:
#     905     model_classes = {"tf": targeted_task["tf"], "pt": targeted_task["pt"]}
# ...
